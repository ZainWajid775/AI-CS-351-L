# %%
# Histogram of petal length

import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import load_iris
import pandas as pd

iris = load_iris()
df = pd.DataFrame(iris.data, columns=iris.feature_names)
df['target'] = iris.target
df['species'] = df['target'].map({i: name for i, name in enumerate(iris.target_names)})

plt.figure(figsize=(6,4))
plt.hist(df['petal length (cm)'], bins=20, edgecolor='black')
plt.title("Histogram of Petal Length")
plt.xlabel("Petal Length (cm)")
plt.ylabel("Frequency")
plt.show()

# %%
# Scatter plot of lenght and width

plt.figure(figsize=(6,4))
sns.scatterplot(data=df, x="sepal length (cm)", y="petal length (cm)", hue="species", palette="Set1")
plt.title("Sepal Length vs Petal Length")
plt.show()

# %%
# Mean sepal lenght bar chart

plt.figure(figsize=(6,4))
sns.barplot(data=df, x="species", y="sepal length (cm)", ci=None, palette="Set2")
plt.title("Mean Sepal Length per Species")
plt.show()
# Out:
# /var/folders/4b/fs9g3qxn63d_7gbb76b56l1m0000gn/T/ipykernel_36141/3899012210.py:4: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(data=df, x="species", y="sepal length (cm)", ci=None, palette="Set2")
# /var/folders/4b/fs9g3qxn63d_7gbb76b56l1m0000gn/T/ipykernel_36141/3899012210.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df, x="species", y="sepal length (cm)", ci=None, palette="Set2")

# %%
# Sepal width across target classes

plt.figure(figsize=(6,4))
sns.boxplot(data=df, x="species", y="sepal width (cm)", palette="Set3")
plt.title("Sepal Width Across Species")
plt.show()
# Out:
# /var/folders/4b/fs9g3qxn63d_7gbb76b56l1m0000gn/T/ipykernel_36141/1092601789.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x="species", y="sepal width (cm)", palette="Set3")
